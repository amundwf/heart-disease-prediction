# %%
import wfdb
import numpy as np
import pandas as pd
import os

# %%
def load_physionet_data_and_get_RRIs_one_subject(database_path, record_name, annotation_format, annotations_only=False):
    # annotation_format: Annotation file extension. E.g. 'ecg' or 'atr'.
    # record_name: The record name of the subject. E.g. 'chf01'.
    # annotations_only: False indicates that the dataset has continuous ECG signal data. True indicates annotations only.

    if annotations_only == False: # Only load ECG signal if it's available in the dataset.
        signal, fields = wfdb.rdsamp(database_path + record_name)
    
    annotations = wfdb.rdann(database_path + record_name, annotation_format)

    # Pre-processing: Remove abnormal heartbeats (keep only heartbeats labeled as 'N' (Normal))
    # Get the sample indices for all normal beats ('N')
    normal_indices = [i for i, symbol in enumerate(annotations.symbol) if symbol == 'N']
    
    # Get the actual sample positions of the normal beats (R-peaks for 'N' labeled beats)
    normal_r_peaks = annotations.sample[normal_indices]
    
    rr_intervals = np.diff(normal_r_peaks) / annotations.fs  # RR intervals in seconds

    # Create a dataframe for the RR intervals
    RRI_data = pd.DataFrame({
        'RR_interval_sec': rr_intervals, # RRIs in seconds
        'sample_start': normal_r_peaks[:-1], # Samples that mark the beginning of each RRI
        'sampling_frequency': annotations.fs,
        'record': record_name
    })

    # Remove RRIs > 2 seconds
    RRI_data_cleaned = RRI_data[RRI_data['RR_interval_sec'] <= 2]

    # Get all unique annotation symbols used in this record
    unique_symbols = set(annotations.symbol)

    if annotations_only == False:
        return RRI_data_cleaned, fields, annotations, unique_symbols
    else:
        return RRI_data_cleaned, annotations, unique_symbols

# %%
# Save cleaned RRI data to CSV files

databases = ['BIDMC-CHF', 'CHF-RR', 'NSR', 'NSR-RR', 'FD']

db_data_directories = {
    'BIDMC-CHF': 'BIDMC-CHF_bidmc-congestive-heart-failure-database-1.0.0/files/',
    'CHF-RR': 'CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/',
    'NSR': 'NSR_mit-bih-normal-sinus-rhythm-database-1.0.0/',
    'NSR-RR': 'NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/',
    'FD': 'FD_fantasia-database-1.0.0/'
}

# Dictionary for annotation formats
db_annotation_formats = {
    'BIDMC-CHF': 'ecg',
    'CHF-RR': 'ecg',
    'NSR': 'atr',
    'NSR-RR': 'ecg',
    'FD': 'ecg'
}

db_annotation_only = {
    'BIDMC-CHF': False,
    'CHF-RR': True,
    'NSR': False,
    'NSR-RR': True,
    'FD': False
}

# Save CSVs in folder: ../data/cleaned_RRIs/

for db_name in databases:
    db_directory = db_data_directories.get(db_name) # Retrieve data directory from the dict
    data_dir_path = '../data/' + db_directory # Directory where the heart data is located
    records_file_path = data_dir_path + 'RECORDS' # The RECORDS file contains the subject code names/labels (e.g. 'chf01', 'chf02', ...)
    annotation_format = db_annotation_formats.get(db_name)
    annotations_only = db_annotation_only.get(db_name)
    
    with open(records_file_path, 'r') as file: # Retrieve the record labels from the RECORDS file
        record_names = file.read().splitlines()
        # For example: record_names = ['chf201', ... 'chf229']

    for record_name in record_names:
        # Get RR interval data
        if annotations_only == True: # Annotations only
            rri_dataframe, annotations, unique_symbols = load_physionet_data_and_get_RRIs_one_subject(
            data_dir_path, record_name, annotation_format, annotations_only
            )
        else: # ECG signal + annotations
            rri_dataframe, fields, annotations, unique_symbols = load_physionet_data_and_get_RRIs_one_subject(
            data_dir_path, record_name, annotation_format, annotations_only
            )
        
        # Save rri_data to CSV
        csv_file_dir = f'../data/cleaned_RRIs/{db_name}/' # The directory where the csv file will be saved
        
        os.makedirs(csv_file_dir, exist_ok=True) # Create the output directory if it doesn't exist
        
        csv_file_name = f'{db_name}_{record_name}_RRI.csv'
        output_file_path = csv_file_dir + csv_file_name
        
        rri_dataframe.to_csv(output_file_path, index=False)
# Out:
# ../data/BIDMC-CHF_bidmc-congestive-heart-failure-database-1.0.0/files/chf01
# ../data/BIDMC-CHF_bidmc-congestive-heart-failure-database-1.0.0/files/chf02
# ../data/BIDMC-CHF_bidmc-congestive-heart-failure-database-1.0.0/files/chf03
# ../data/BIDMC-CHF_bidmc-congestive-heart-failure-database-1.0.0/files/chf04
# ../data/BIDMC-CHF_bidmc-congestive-heart-failure-database-1.0.0/files/chf05
# ../data/BIDMC-CHF_bidmc-congestive-heart-failure-database-1.0.0/files/chf06
# ../data/BIDMC-CHF_bidmc-congestive-heart-failure-database-1.0.0/files/chf07
# ../data/BIDMC-CHF_bidmc-congestive-heart-failure-database-1.0.0/files/chf08
# ../data/BIDMC-CHF_bidmc-congestive-heart-failure-database-1.0.0/files/chf09
# ../data/BIDMC-CHF_bidmc-congestive-heart-failure-database-1.0.0/files/chf10
# ../data/BIDMC-CHF_bidmc-congestive-heart-failure-database-1.0.0/files/chf11
# ../data/BIDMC-CHF_bidmc-congestive-heart-failure-database-1.0.0/files/chf12
# ../data/BIDMC-CHF_bidmc-congestive-heart-failure-database-1.0.0/files/chf13
# ../data/BIDMC-CHF_bidmc-congestive-heart-failure-database-1.0.0/files/chf14
# ../data/BIDMC-CHF_bidmc-congestive-heart-failure-database-1.0.0/files/chf15
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf201
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf202
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf203
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf204
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf205
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf206
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf207
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf208
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf209
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf210
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf211
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf212
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf213
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf214
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf215
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf216
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf217
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf218
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf219
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf220
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf221
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf222
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf223
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf224
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf225
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf226
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf227
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf228
# ../data/CHF-RR_congestive-heart-failure-rr-interval-database-1.0.0/chf229
# ../data/NSR_mit-bih-normal-sinus-rhythm-database-1.0.0/16265
# ../data/NSR_mit-bih-normal-sinus-rhythm-database-1.0.0/16272
# ../data/NSR_mit-bih-normal-sinus-rhythm-database-1.0.0/16273
# ../data/NSR_mit-bih-normal-sinus-rhythm-database-1.0.0/16420
# ../data/NSR_mit-bih-normal-sinus-rhythm-database-1.0.0/16483
# ../data/NSR_mit-bih-normal-sinus-rhythm-database-1.0.0/16539
# ../data/NSR_mit-bih-normal-sinus-rhythm-database-1.0.0/16773
# ../data/NSR_mit-bih-normal-sinus-rhythm-database-1.0.0/16786
# ../data/NSR_mit-bih-normal-sinus-rhythm-database-1.0.0/16795
# ../data/NSR_mit-bih-normal-sinus-rhythm-database-1.0.0/17052
# ../data/NSR_mit-bih-normal-sinus-rhythm-database-1.0.0/17453
# ../data/NSR_mit-bih-normal-sinus-rhythm-database-1.0.0/18177
# ../data/NSR_mit-bih-normal-sinus-rhythm-database-1.0.0/18184
# ../data/NSR_mit-bih-normal-sinus-rhythm-database-1.0.0/19088
# ../data/NSR_mit-bih-normal-sinus-rhythm-database-1.0.0/19090
# ../data/NSR_mit-bih-normal-sinus-rhythm-database-1.0.0/19093
# ../data/NSR_mit-bih-normal-sinus-rhythm-database-1.0.0/19140
# ../data/NSR_mit-bih-normal-sinus-rhythm-database-1.0.0/19830
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr001
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr002
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr003
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr004
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr005
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr006
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr007
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr008
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr009
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr010
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr011
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr012
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr013
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr014
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr015
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr016
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr017
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr018
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr019
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr020
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr021
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr022
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr023
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr024
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr025
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr026
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr027
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr028
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr029
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr030
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr031
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr032
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr033
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr034
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr035
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr036
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr037
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr038
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr039
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr040
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr041
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr042
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr043
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr044
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr045
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr046
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr047
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr048
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr049
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr050
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr051
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr052
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr053
# ../data/NSR-RR_normal-sinus-rhythm-rr-interval-database-1.0.0/nsr054
# ../data/FD_fantasia-database-1.0.0/f1o01
# ../data/FD_fantasia-database-1.0.0/f1o02
# ../data/FD_fantasia-database-1.0.0/f1o03
# ../data/FD_fantasia-database-1.0.0/f1o04
# ../data/FD_fantasia-database-1.0.0/f1o05
# ../data/FD_fantasia-database-1.0.0/f1o06
# ../data/FD_fantasia-database-1.0.0/f1o07
# ../data/FD_fantasia-database-1.0.0/f1o08
# ../data/FD_fantasia-database-1.0.0/f1o09
# ../data/FD_fantasia-database-1.0.0/f1o10
# ../data/FD_fantasia-database-1.0.0/f1y01
# ../data/FD_fantasia-database-1.0.0/f1y02
# ../data/FD_fantasia-database-1.0.0/f1y03
# ../data/FD_fantasia-database-1.0.0/f1y04
# ../data/FD_fantasia-database-1.0.0/f1y05
# ../data/FD_fantasia-database-1.0.0/f1y06
# ../data/FD_fantasia-database-1.0.0/f1y07
# ../data/FD_fantasia-database-1.0.0/f1y08
# ../data/FD_fantasia-database-1.0.0/f1y09
# ../data/FD_fantasia-database-1.0.0/f1y10
# ../data/FD_fantasia-database-1.0.0/f2o01
# ../data/FD_fantasia-database-1.0.0/f2o02
# ../data/FD_fantasia-database-1.0.0/f2o03
# ../data/FD_fantasia-database-1.0.0/f2o04
# ../data/FD_fantasia-database-1.0.0/f2o05
# ../data/FD_fantasia-database-1.0.0/f2o06
# ../data/FD_fantasia-database-1.0.0/f2o07
# ../data/FD_fantasia-database-1.0.0/f2o08
# ../data/FD_fantasia-database-1.0.0/f2o09
# ../data/FD_fantasia-database-1.0.0/f2o10
# ../data/FD_fantasia-database-1.0.0/f2y01
# ../data/FD_fantasia-database-1.0.0/f2y02
# ../data/FD_fantasia-database-1.0.0/f2y03
# ../data/FD_fantasia-database-1.0.0/f2y04
# ../data/FD_fantasia-database-1.0.0/f2y05
# ../data/FD_fantasia-database-1.0.0/f2y06
# ../data/FD_fantasia-database-1.0.0/f2y07
# ../data/FD_fantasia-database-1.0.0/f2y08
# ../data/FD_fantasia-database-1.0.0/f2y09
# ../data/FD_fantasia-database-1.0.0/f2y10

# %%
# Partition each subject's RRI data into segments.
# This is done by adding a column 'segment_id' for a chosen segment length (e.g. N=500).
# Each updated dataframe is saved to CSV.

# Segment length
N = 500

# Base directory where the CSV files are stored
base_dir = '../data/cleaned_RRIs'

# Directory where the CSV files with segment ids are to be stored
with_segment_ids_dir = f'../data/cleaned_RRIs/with_segment_ids_N{N}'
print(f'with_segment_ids_dir: {with_segment_ids_dir}')
os.makedirs(with_segment_ids_dir, exist_ok=True)

# List of subdirectories for each database
databases = ['BIDMC-CHF', 'CHF-RR', 'NSR', 'NSR-RR', 'FD']
databases_nsr = ['NSR', 'NSR-RR', 'FD'] # no heart disease present (label = 0)
databases_chf = ['BIDMC-CHF', 'CHF-RR'] # heart disease present (label = 1)

# Iterate through each database
for db in databases:
    print(f"\nProcessing database: {db}")
    db_path_load = os.path.join(base_dir, db)
    db_path_save = os.path.join(with_segment_ids_dir, db)
    os.makedirs(db_path_save, exist_ok=True)
    
    # Check if the directory exists
    if os.path.exists(db_path_load):
        for file in os.listdir(db_path_load):
            if file.endswith(".csv"):
                print(f"  Processing subject file: {file}")
                
                # Load each CSV file
                file_path_load = os.path.join(db_path_load, file)
                df_rris = pd.read_csv(file_path_load) # RRI data of one subject
                subject_code_name = df_rris['record'].iloc[0] # Retrieve the record (subject code name)
                subject_code_name = str(subject_code_name) # Convert to a string to ensure it is treated as text

                # Add column 'segment_id'
                if 'segment_id' not in df_rris.columns:
                    df_rris['segment_id'] = pd.Series(dtype='object')

                # Add column 'label'
                if 'label' not in df_rris.columns:
                    df_rris['label'] = pd.Series(dtype='int64')
                if db in databases_nsr:
                    df_rris['label'] = 0
                elif db in databases_chf:
                    df_rris['label'] = 1
                else:
                    df_rris['label'] = np.nan
                    print(f"Warning: Database [{db}] was not in the listed CHF or NSR databases.")
 
                # Partition the data into intervals of N RRIs
                num_segments = len(df_rris) // N
                
                # Process complete segments
                for i in range(num_segments):
                    segment_no = i+1
                    segment_id = f"{subject_code_name}_{str(segment_no).zfill(len(str(num_segments+1)))}"

                    # Current RRI segment
                    df_segment = df_rris.iloc[i*N:(i+1)*N]

                    # Add segment_id to the RRI rows corresponding to the segment:
                    df_rris.iloc[i*N:(i+1)*N, df_rris.columns.get_loc('segment_id')] = segment_id

                # Ensure all missing or empty values of segment_id are explicitly set to NaN for clarity
                df_rris.loc[df_rris['segment_id'].isna(), 'segment_id'] = np.nan
                
                # Save to CSV
                file_path_save = os.path.join(db_path_save, file)
                df_rris.to_csv(file_path_save, index=False)

print("\nProcessing complete.")
# Out:
# Segment length: N = 500
#
# with_segment_ids_dir: ../data/cleaned_RRIs/with_segment_ids_N500
#
# Processing database: BIDMC-CHF
#   Processing subject file: BIDMC-CHF_chf01_RRI.csv
#   Processing subject file: BIDMC-CHF_chf02_RRI.csv
#   Processing subject file: BIDMC-CHF_chf03_RRI.csv
#   Processing subject file: BIDMC-CHF_chf04_RRI.csv
#   Processing subject file: BIDMC-CHF_chf05_RRI.csv
#   Processing subject file: BIDMC-CHF_chf06_RRI.csv
#   Processing subject file: BIDMC-CHF_chf07_RRI.csv
#   Processing subject file: BIDMC-CHF_chf08_RRI.csv
#   Processing subject file: BIDMC-CHF_chf09_RRI.csv
#   Processing subject file: BIDMC-CHF_chf10_RRI.csv
#   Processing subject file: BIDMC-CHF_chf11_RRI.csv
#   Processing subject file: BIDMC-CHF_chf12_RRI.csv
#   Processing subject file: BIDMC-CHF_chf13_RRI.csv
#   Processing subject file: BIDMC-CHF_chf14_RRI.csv
#   Processing subject file: BIDMC-CHF_chf15_RRI.csv
#
# Processing database: CHF-RR
#   Processing subject file: CHF-RR_chf201_RRI.csv
#   Processing subject file: CHF-RR_chf202_RRI.csv
#   Processing subject file: CHF-RR_chf203_RRI.csv
#   Processing subject file: CHF-RR_chf204_RRI.csv
#   Processing subject file: CHF-RR_chf205_RRI.csv
#   Processing subject file: CHF-RR_chf206_RRI.csv
#   Processing subject file: CHF-RR_chf207_RRI.csv
#   Processing subject file: CHF-RR_chf208_RRI.csv
#   Processing subject file: CHF-RR_chf209_RRI.csv
#   Processing subject file: CHF-RR_chf210_RRI.csv
#   Processing subject file: CHF-RR_chf211_RRI.csv
#   Processing subject file: CHF-RR_chf212_RRI.csv
#   Processing subject file: CHF-RR_chf213_RRI.csv
#   Processing subject file: CHF-RR_chf214_RRI.csv
#   Processing subject file: CHF-RR_chf215_RRI.csv
#   Processing subject file: CHF-RR_chf216_RRI.csv
#   Processing subject file: CHF-RR_chf217_RRI.csv
#   Processing subject file: CHF-RR_chf218_RRI.csv
#   Processing subject file: CHF-RR_chf219_RRI.csv
#   Processing subject file: CHF-RR_chf220_RRI.csv
#   Processing subject file: CHF-RR_chf221_RRI.csv
#   Processing subject file: CHF-RR_chf222_RRI.csv
#   Processing subject file: CHF-RR_chf223_RRI.csv
#   Processing subject file: CHF-RR_chf224_RRI.csv
#   Processing subject file: CHF-RR_chf225_RRI.csv
#   Processing subject file: CHF-RR_chf226_RRI.csv
#   Processing subject file: CHF-RR_chf227_RRI.csv
#   Processing subject file: CHF-RR_chf228_RRI.csv
#   Processing subject file: CHF-RR_chf229_RRI.csv
#
# Processing database: NSR
#   Processing subject file: NSR_16265_RRI.csv
#   Processing subject file: NSR_16272_RRI.csv
#   Processing subject file: NSR_16273_RRI.csv
#   Processing subject file: NSR_16420_RRI.csv
#   Processing subject file: NSR_16483_RRI.csv
#   Processing subject file: NSR_16539_RRI.csv
#   Processing subject file: NSR_16773_RRI.csv
#   Processing subject file: NSR_16786_RRI.csv
#   Processing subject file: NSR_16795_RRI.csv
#   Processing subject file: NSR_17052_RRI.csv
#   Processing subject file: NSR_17453_RRI.csv
#   Processing subject file: NSR_18177_RRI.csv
#   Processing subject file: NSR_18184_RRI.csv
#   Processing subject file: NSR_19088_RRI.csv
#   Processing subject file: NSR_19090_RRI.csv
#   Processing subject file: NSR_19093_RRI.csv
#   Processing subject file: NSR_19140_RRI.csv
#   Processing subject file: NSR_19830_RRI.csv
#
# Processing database: NSR-RR
#   Processing subject file: NSR-RR_nsr001_RRI.csv
#   Processing subject file: NSR-RR_nsr002_RRI.csv
#   Processing subject file: NSR-RR_nsr003_RRI.csv
#   Processing subject file: NSR-RR_nsr004_RRI.csv
#   Processing subject file: NSR-RR_nsr005_RRI.csv
#   Processing subject file: NSR-RR_nsr006_RRI.csv
#   Processing subject file: NSR-RR_nsr007_RRI.csv
#   Processing subject file: NSR-RR_nsr008_RRI.csv
#   Processing subject file: NSR-RR_nsr009_RRI.csv
#   Processing subject file: NSR-RR_nsr010_RRI.csv
#   Processing subject file: NSR-RR_nsr011_RRI.csv
#   Processing subject file: NSR-RR_nsr012_RRI.csv
#   Processing subject file: NSR-RR_nsr013_RRI.csv
#   Processing subject file: NSR-RR_nsr014_RRI.csv
#   Processing subject file: NSR-RR_nsr015_RRI.csv
#   Processing subject file: NSR-RR_nsr016_RRI.csv
#   Processing subject file: NSR-RR_nsr017_RRI.csv
#   Processing subject file: NSR-RR_nsr018_RRI.csv
#   Processing subject file: NSR-RR_nsr019_RRI.csv
#   Processing subject file: NSR-RR_nsr020_RRI.csv
#   Processing subject file: NSR-RR_nsr021_RRI.csv
#   Processing subject file: NSR-RR_nsr022_RRI.csv
#   Processing subject file: NSR-RR_nsr023_RRI.csv
#   Processing subject file: NSR-RR_nsr024_RRI.csv
#   Processing subject file: NSR-RR_nsr025_RRI.csv
#   Processing subject file: NSR-RR_nsr026_RRI.csv
#   Processing subject file: NSR-RR_nsr027_RRI.csv
#   Processing subject file: NSR-RR_nsr028_RRI.csv
#   Processing subject file: NSR-RR_nsr029_RRI.csv
#   Processing subject file: NSR-RR_nsr030_RRI.csv
#   Processing subject file: NSR-RR_nsr031_RRI.csv
#   Processing subject file: NSR-RR_nsr032_RRI.csv
#   Processing subject file: NSR-RR_nsr033_RRI.csv
#   Processing subject file: NSR-RR_nsr034_RRI.csv
#   Processing subject file: NSR-RR_nsr035_RRI.csv
#   Processing subject file: NSR-RR_nsr036_RRI.csv
#   Processing subject file: NSR-RR_nsr037_RRI.csv
#   Processing subject file: NSR-RR_nsr038_RRI.csv
#   Processing subject file: NSR-RR_nsr039_RRI.csv
#   Processing subject file: NSR-RR_nsr040_RRI.csv
#   Processing subject file: NSR-RR_nsr041_RRI.csv
#   Processing subject file: NSR-RR_nsr042_RRI.csv
#   Processing subject file: NSR-RR_nsr043_RRI.csv
#   Processing subject file: NSR-RR_nsr044_RRI.csv
#   Processing subject file: NSR-RR_nsr045_RRI.csv
#   Processing subject file: NSR-RR_nsr046_RRI.csv
#   Processing subject file: NSR-RR_nsr047_RRI.csv
#   Processing subject file: NSR-RR_nsr048_RRI.csv
#   Processing subject file: NSR-RR_nsr049_RRI.csv
#   Processing subject file: NSR-RR_nsr050_RRI.csv
#   Processing subject file: NSR-RR_nsr051_RRI.csv
#   Processing subject file: NSR-RR_nsr052_RRI.csv
#   Processing subject file: NSR-RR_nsr053_RRI.csv
#   Processing subject file: NSR-RR_nsr054_RRI.csv
#
# Processing database: FD
#   Processing subject file: FD_f1o01_RRI.csv
#   Processing subject file: FD_f1o02_RRI.csv
#   Processing subject file: FD_f1o03_RRI.csv
#   Processing subject file: FD_f1o04_RRI.csv
#   Processing subject file: FD_f1o05_RRI.csv
#   Processing subject file: FD_f1o06_RRI.csv
#   Processing subject file: FD_f1o07_RRI.csv
#   Processing subject file: FD_f1o08_RRI.csv
#   Processing subject file: FD_f1o09_RRI.csv
#   Processing subject file: FD_f1o10_RRI.csv
#   Processing subject file: FD_f1y01_RRI.csv
#   Processing subject file: FD_f1y02_RRI.csv
#   Processing subject file: FD_f1y03_RRI.csv
#   Processing subject file: FD_f1y04_RRI.csv
#   Processing subject file: FD_f1y05_RRI.csv
#   Processing subject file: FD_f1y06_RRI.csv
#   Processing subject file: FD_f1y07_RRI.csv
#   Processing subject file: FD_f1y08_RRI.csv
#   Processing subject file: FD_f1y09_RRI.csv
#   Processing subject file: FD_f1y10_RRI.csv
#   Processing subject file: FD_f2o01_RRI.csv
#   Processing subject file: FD_f2o02_RRI.csv
#   Processing subject file: FD_f2o03_RRI.csv
#   Processing subject file: FD_f2o04_RRI.csv
#   Processing subject file: FD_f2o05_RRI.csv
#   Processing subject file: FD_f2o06_RRI.csv
#   Processing subject file: FD_f2o07_RRI.csv
#   Processing subject file: FD_f2o08_RRI.csv
#   Processing subject file: FD_f2o09_RRI.csv
#   Processing subject file: FD_f2o10_RRI.csv
#   Processing subject file: FD_f2y01_RRI.csv
#   Processing subject file: FD_f2y02_RRI.csv
#   Processing subject file: FD_f2y03_RRI.csv
#   Processing subject file: FD_f2y04_RRI.csv
#   Processing subject file: FD_f2y05_RRI.csv
#   Processing subject file: FD_f2y06_RRI.csv
#   Processing subject file: FD_f2y07_RRI.csv
#   Processing subject file: FD_f2y08_RRI.csv
#   Processing subject file: FD_f2y09_RRI.csv
#   Processing subject file: FD_f2y10_RRI.csv
#
# Processing complete.
