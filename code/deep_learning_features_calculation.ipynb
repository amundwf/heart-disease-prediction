# %%
import os
import numpy as np
import pandas as pd
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt

# %%
# Implement ConvPool-CNN-C architecture for calculating deep learning features, similar to Wang et al.

class ConvPoolCNN(nn.Module):
    """
    Implementation of the ConvPool-CNN-C architecture.
    Ref.: Springenberg et al. (2015), 'Striving for Simplicity: The All Convolutional Net'.
    Choice of network parameters (filters number, kernel size) for each of the Conv1D layers: (32, 60), (32, 60), (32, 30), (32, 30).
    """

    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=32, kernel_size=60, padding="same")
        self.conv2 = nn.Conv1d(in_channels=32, out_channels=32, kernel_size=60, padding="same")

        # MaxPooling1D
        self.pool = nn.MaxPool1d(kernel_size=2) # stride = same as kernel size by default

        self.conv3 = nn.Conv1d(in_channels=32, out_channels=32, kernel_size=30, padding="same")
        self.conv4 = nn.Conv1d(in_channels=32, out_channels=32, kernel_size=30, padding="same")

        # GlobalAveragePooling1D (Deep learning features extractor?)
        # Output layer. Deep learning features (32 dim).
        self.global_avg_pool = nn.AdaptiveAvgPool1d(output_size=1)

        self.fc = nn.Linear(32, 1) # Raw logits. For prediction/inference.

    def forward_features(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = self.pool(x)
        x = self.conv3(x)
        x = F.relu(x)
        x = self.conv4(x)
        x = F.relu(x)
        x = self.global_avg_pool(x)
        # Output layer. Deep-learning features (32 of them)
        x = x.view(-1, 32)  # shape: [batch_size, 32]
        return x

    def forward(self, x):
        # If wanting to get a final output (e.g. regression or classification)
        x = self.forward_features(x)
        x = self.fc(x)
        return x

# Simple feed forward neural network (FFN), for testing purposes
class SimpleFFN(nn.Module):
    def __init__(self, input_dim=500):
        super().__init__()
        # Flatten the 1D input
        self.fc1 = nn.Linear(input_dim, 32)
        self.fc2 = nn.Linear(32, 1)

    def forward(self, x):
        # x shape: [batch_size, 1, seq_len]
        # Flatten out the sequence dimension
        x = x.squeeze(1)             # [batch_size, seq_len]
        x = x.view(x.size(0), -1)    # [batch_size, seq_len]
        x = F.relu(self.fc1(x))      # [batch_size, 32]
        x = self.fc2(x)              # [batch_size, 1] (logits)
        return x

class CNN_more_simple(nn.Module):
    """
    Based on the ConvPool-CNN-C architecture, but with some layers removed.
    Ref.: Springenberg et al. (2015), 'Striving for Simplicity: The All Convolutional Net'.
    Choice of network parameters (filters number, kernel size) for each of the Conv1D layers: (32, 60), (32, 60), (32, 30), (32, 30).
    """

    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=32, kernel_size=60, padding="same")

        # MaxPooling1D
        self.pool = nn.MaxPool1d(kernel_size=2) # stride = same as kernel size by default

        self.conv3 = nn.Conv1d(in_channels=32, out_channels=32, kernel_size=30, padding="same")

        # GlobalAveragePooling1D (Deep learning features extractor?)
        # Output layer. Deep learning features (32 dim).
        self.global_avg_pool = nn.AdaptiveAvgPool1d(output_size=1)

        self.fc = nn.Linear(32, 1) # Raw logits. For prediction/inference.

    def forward_features(self, x):
        x = self.conv1(x)
        x = F.relu(x)

        x = self.pool(x)

        x = self.conv3(x)
        x = F.relu(x)

        x = self.global_avg_pool(x)

        # Output layer. Deep-learning features (32 of them)
        x = x.view(-1, 32)  # shape: [batch_size, 32]
        return x

    def forward(self, x):
        # If wanting to get a final output (e.g. regression or classification)
        x = self.forward_features(x)
        x = self.fc(x)
        return x

class CNN_even_more_simple(nn.Module):
    """
    Based on the ConvPool-CNN-C architecture, but with some layers removed.
    Ref.: Springenberg et al. (2015), 'Striving for Simplicity: The All Convolutional Net'.
    Choice of network parameters (filters number, kernel size) for each of the Conv1D layers: (32, 60), (32, 60), (32, 30), (32, 30).
    """

    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=32, kernel_size=60, padding="same")

        # MaxPooling1D
        self.pool = nn.MaxPool1d(kernel_size=2) # stride = same as kernel size by default

        # GlobalAveragePooling1D (Deep learning features extractor?)
        # Output layer. Deep learning features (32 dim).
        self.global_avg_pool = nn.AdaptiveAvgPool1d(output_size=1)

        self.fc = nn.Linear(32, 1) # Raw logits. For prediction/inference.

    def forward_features(self, x):
        x = self.conv1(x)
        x = F.relu(x)

        x = self.global_avg_pool(x)

        # Output layer. Deep-learning features (32 of them)
        x = x.view(-1, 32)  # shape: [batch_size, 32]
        return x

    def forward(self, x):
        # If wanting to get a final output (e.g. regression or classification)
        x = self.forward_features(x)
        x = self.fc(x)
        return x

# %%
# Create a Pytorch Dataset.

class RRIDataset(Dataset):
    """
    Expects a DataFrame where each row is one RRI segment with columns:
        segment_id (str)
        RR_interval_sec (list of floats)
        label (0 or 1)
        [optionally database or other info about the segment, which we can ignore here]
    """
    def __init__(self, df_segments):
        self.df = df_segments.reset_index(drop=True)

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]

        # The time-series of RR intervals
        rri_list = row["RR_interval_sec"]

        # Convert to torch.FloatTensor.
        # Shape will be [sequence_length]. We unsqueeze(0) so that
        # final shape is [1, sequence_length] (i.e. one channel)
        rri_tensor = torch.tensor(rri_list, dtype=torch.float).unsqueeze(0)

        # Convert label to float. For BCEWithLogitsLoss, label should be float 0.0 or 1.0
        label = torch.tensor(row["label"], dtype=torch.float)

        return rri_tensor, label

# %%
# Train model (test script, using only a small subset of the training set)

# Train/val/test sets subjects, overview
data_dir = "..//data//dataset_splits//"

filename_train = "db1_training_set_1.csv"
filename_val = "db1_validation_set_1.csv"
filename_test = "db1_test_set_1.csv"

# Import data (training set)
path_train = data_dir + filename_train
path_val = data_dir + filename_val
path_test = data_dir + filename_test

def group_subject_RRI_data_by_segment_id(df_subject):
    # df_subject: DataFrame with the following columns: , RR_interval_sec, sample_start, sampling_frequency, record, segment_id, label
    # Returns a new DataFrame with columns: segment_id, RR_interval_sec (as a list), label.
    
    # Group by segment_id, gather the RRI arrays
    df_segmented = (
        df_subject
        .groupby("segment_id")
        .agg({"RR_interval_sec": list,
              "label": "first"})
        .reset_index()
    )
    return df_segmented


def create_segmented_subset_of_data(dataset_split_info_file_path, base_dir, n_subjects='all', n_segments='all'):
    """
    1) Reads the partition CSV (e.g. db1_training_set_1.csv), which has columns
       ['subject_id', 'database', 'CHF'].
    2) Randomly selects n_subjects from that partition.
    3) For each selected subject, reads the corresponding CSV from 
       `base_dir/<database>/<database>_<subject_id>_RRI.csv`, groups by segment_id, and 
       randomly chooses n_segments. 
    4) Concatenates the results into a single DataFrame and returns it.
    
    Parameters
    ----------
    dataset_split_info_file : str
        Path to the partition file, e.g. "../data/dataset_splits/db1_training_set_1.csv"
    base_dir : str
        Path to the root folder that contains subfolders like "BIDMC-CHF", "NSR", "FD", etc.
    n_subjects : int
        Number of subjects to randomly sample from the partition file.
    n_segments : int
        Number of segments to randomly sample from each subject.

    Returns
    -------
    subset_df : pd.DataFrame
        A segment-level DataFrame with columns: ['segment_id', 'RR_interval_sec', 'label']
    """
    # Load the partition info
    df_partition = pd.read_csv(dataset_split_info_file_path)
    
    # Select subjects from the partition
    if isinstance(n_subjects, str) and n_subjects.lower() == 'all':
        df_chosen = df_partition
    else:
        # Split the partition by CHF status
        df_chf_1 = df_partition[df_partition['CHF'] == 1]
        df_chf_0 = df_partition[df_partition['CHF'] == 0]
        
        # Ensure n_subjects is at least 2 to accommodate both classes
        n_subj = max(2, min(len(df_partition), n_subjects))
    
        # Sample approximately the same number of CHF=1 and CHF=0
        n_chf_1 = n_subj // 2
        n_chf_0 = n_subj - n_chf_1
        
        # Sample from each class
        df_chosen_chf_1 = df_chf_1.sample(n=min(len(df_chf_1), n_chf_1))
        df_chosen_chf_0 = df_chf_0.sample(n=min(len(df_chf_0), n_chf_0))
        
        # Combine the samples
        df_chosen = pd.concat([df_chosen_chf_1, df_chosen_chf_0])

    # For each chosen subject, read the RRI CSV, group by segment_id, then optionally sample segments
    subset_dfs = []
    for _, row in df_chosen.iterrows():
        subject_id = row['subject_id']
        db_name = row['database']  # e.g. "BIDMC-CHF", "NSR", "FD", etc.
        db_name = 'FD' if db_name == 'Fantasia' else db_name # Special case fix
        subject_label = row['CHF']  # e.g. 0 or 1

        # Construct the path to the subject's CSV
        # e.g.: "../data/cleaned_RRIs/with_segment_ids_N500/BIDMC-CHF/chf02_RRI.csv"
        csv_filename = f"{db_name}_{subject_id}_RRI.csv"  
        csv_path = os.path.join(base_dir, db_name, csv_filename)
        
        # Read the subject's data
        df_subject = pd.read_csv(csv_path)
        
        # Group by segment_id
        df_segmented = group_subject_RRI_data_by_segment_id(df_subject)

        df_segmented['database'] = db_name
        df_segmented['subject_id'] = subject_id
        # Optionally override the label (to ensure subject-level label is consistent)
        df_segmented['label'] = subject_label
        
        # Select segments from this subject
        if isinstance(n_segments, str) and n_segments.lower() == 'all':
            # Take all segments from this subject
            df_sampled = df_segmented
        else:
            # Randomly sample n_segments
            n_segs = min(len(df_segmented), n_segments)
            df_sampled = df_segmented.sample(n=n_segs)

        subset_dfs.append(df_sampled)
    
    # Concatenate all chosen subjects into one DataFrame
    subset_segmented_df = pd.concat(subset_dfs, ignore_index=True)
    return subset_segmented_df

base_dir = os.path.join("..", "data", "cleaned_RRIs", "with_segment_ids_N500")
dataset_splits_dir = os.path.join("..", "data", "dataset_splits")
train_split_file = "db1_training_set_1.csv"
val_split_file = "db1_validation_set_1.csv"

train_split_file_path = os.path.join(dataset_splits_dir, train_split_file)
val_split_file_path = os.path.join(dataset_splits_dir, val_split_file)

# Create a small subset with 2 random subjects, 5 random segments each
df_train_subset = create_segmented_subset_of_data(
    dataset_split_info_file_path=train_split_file_path, 
    base_dir=base_dir, 
    n_subjects=10, 
    n_segments=1
)

# # Load the (entire) training set (to view more stats on segments etc. for the full set)
df_train = create_segmented_subset_of_data(dataset_split_info_file_path=train_split_file_path, base_dir=base_dir)

# Load the (entire) validation set
df_val = create_segmented_subset_of_data(dataset_split_info_file_path=val_split_file_path, base_dir=base_dir)

def print_segment_stats(df, set_name):
    """
    Prints the number of segments per subject and the average number of segments.

    Parameters:
    - df (pd.DataFrame): The DataFrame containing the dataset.
    - set_name (str): Name of the dataset (e.g., 'Training', 'Validation').
    """
    # Group by 'subject_id' and count the number of segments
    segments_per_subject = df.groupby('subject_id').size()
    
    print(f"--- {set_name} Set Segment Statistics ---")
    print("Number of Segments per Subject:")
    print(segments_per_subject)
    
    # Calculate the average number of segments
    average_segments = segments_per_subject.mean()
    print(f"\nAverage Number of Segments per Subject: {average_segments:.2f}")
    total_segments = segments_per_subject.sum()
    print(f"Total Number of Segments: {total_segments:.2f}\n")

print_segment_stats(df_train_subset, "Training (subset)")
print_segment_stats(df_train, "Training (whole)")
print_segment_stats(df_val, "Validation")
# Out:
# train_split_file_path: ..\data\dataset_splits\db1_training_set_1.csv
# val_split_file_path: ..\data\dataset_splits\db1_validation_set_1.csv
#   segment_id                                    RR_interval_sec  label  \
# 0  chf03_150  [0.932, 0.94, 0.94, 0.94, 0.956, 0.944, 0.952,...      1
# 1  chf06_078  [0.568, 0.616, 0.6, 0.448, 0.684, 0.624, 0.596...      1
# 2  chf09_014  [0.584, 0.572, 0.576, 0.584, 0.572, 0.572, 0.5...      1
# 3  chf02_128  [0.608, 1.212, 0.612, 1.244, 0.62, 0.62, 0.612...      1
# 4  chf04_098  [0.648, 0.736, 0.684, 0.716, 1.356, 0.692, 0.6...      1
# 5  16483_032  [0.7421875, 0.703125, 0.703125, 0.703125, 0.67...      0
# 6  16795_057  [0.6875, 0.640625, 0.7109375, 0.6796875, 0.648...      0
# 7   f1o08_09  [0.924, 0.876, 0.916, 0.912, 0.884, 0.892, 0.9...      0
# 8   f2o01_07  [1.0, 1.012, 0.988, 0.972, 1.028, 1.06, 1.08, ...      0
# 9   f1o02_10  [1.068, 1.056, 1.064, 1.06, 1.064, 1.06, 1.064...      0
#
#     database subject_id
# 0  BIDMC-CHF      chf03
# 1  BIDMC-CHF      chf06
# 2  BIDMC-CHF      chf09
# 3  BIDMC-CHF      chf02
# 4  BIDMC-CHF      chf04
# 5        NSR      16483
# 6        NSR      16795
# 7         FD      f1o08
# 8         FD      f2o01
# 9         FD      f1o02
#      segment_id                                    RR_interval_sec  label  \
# 0     chf14_001  [0.776, 0.812, 0.82, 0.824, 0.84, 0.816, 0.82,...      1
# 1     chf14_002  [0.748, 0.752, 0.756, 0.744, 0.748, 0.752, 0.7...      1
# 2     chf14_003  [0.772, 0.772, 0.788, 0.812, 0.76, 0.776, 0.77...      1
# 3     chf14_004  [0.784, 0.788, 0.78, 0.784, 0.776, 0.788, 0.79...      1
# 4     chf14_005  [0.776, 0.76, 0.776, 0.752, 0.756, 0.764, 0.76...      1
# ...         ...                                                ...    ...
# 1089   f1o07_10  [1.06, 1.04, 1.052, 1.064, 1.056, 1.044, 1.056...      0
# 1090   f1o07_11  [1.02, 1.06, 1.056, 1.064, 1.084, 1.076, 1.052...      0
# 1091   f1o07_12  [1.02, 1.004, 0.98, 0.996, 0.996, 0.984, 0.972...      0
# 1092   f1o07_13  [1.06, 1.044, 1.08, 1.096, 1.108, 1.1, 1.084, ...      0
# 1093   f1o07_14  [1.092, 1.048, 1.04, 1.012, 1.02, 1.028, 1.04,...      0
#
#        database subject_id
# 0     BIDMC-CHF      chf14
# 1     BIDMC-CHF      chf14
# 2     BIDMC-CHF      chf14
# 3     BIDMC-CHF      chf14
# 4     BIDMC-CHF      chf14
# ...         ...        ...
# 1089         FD      f1o07
# 1090         FD      f1o07
# 1091         FD      f1o07
# 1092         FD      f1o07
# 1093         FD      f1o07
#
# [1094 rows x 5 columns]
# --- Training (subset) Set Segment Statistics ---
# Number of Segments per Subject:
# subject_id
# 16483    1
# 16795    1
# chf02    1
# chf03    1
# chf04    1
# chf06    1
# chf09    1
# f1o02    1
# f1o08    1
# f2o01    1
# dtype: int64
#
# Average Number of Segments per Subject: 1.00
# Total Number of Segments: 10.00
#
# --- Training (whole) Set Segment Statistics ---
# Number of Segments per Subject:
# subject_id
# 16483    208
# 16539    216
# 16773    163
# 16795    173
# 17052    174
# 17453    201
# 18177    231
# 18184    204
# 19088    195
# 19090    162
# 19093    150
# 19140    193
# 19830    218
# chf02    181
# chf03    156
# chf04    221
# chf05    236
# chf06    223
# chf07    180
# chf08    179
# chf09    228
# chf11    230
# chf15    224
# f1o01     14
# f1o02     13
# f1o03     14
# f1o04     12
# f1o06     12
# f1o08     16
# f1o09      9
# f1o10     16
# f1y01     17
# f1y02     13
# f1y03     15
# f1y05     13
# f1y06     14
# f1y07     11
# f1y08     14
# f1y09     16
# f2o01     14
# f2o02     12
# f2o03     12
# f2o04     13
# f2o05     16
# f2o06     10
# f2o07     11
# f2o09     12
# f2o10     16
# f2y01     16
# f2y03     13
# f2y04     17
# f2y06     13
# f2y07     12
# f2y09     16
# f2y10     14
# dtype: int64
#
# Average Number of Segments per Subject: 90.58
# Total Number of Segments: 4982.00
#
# --- Validation Set Segment Statistics ---
# Number of Segments per Subject:
# subject_id
# 16273    179
# 16420    204
# 16786    203
# chf13    230
# chf14    186
# f1o05     11
# f1o07     14
# f1y04     10
# f2o08     12
# f2y02     13
# f2y05     18
# f2y08     14
# dtype: int64
#
# Average Number of Segments per Subject: 91.17
# Total Number of Segments: 1094.00

# %%
# Create the Dataset & DataLoader

#df_train = df_train_subset  # Subset
df_train = df_train  # Whole set
df_val = df_val

# 1) Wrap the df in a Dataset
train_dataset = RRIDataset(df_train)
val_dataset = RRIDataset(df_val)

# 2) Make a DataLoader
batch_sz = 16 # batch size
train_loader = DataLoader(train_dataset, batch_size=batch_sz, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_sz, shuffle=False)

# Verify shape by viewing an example batch
for batch_rri, batch_labels in train_loader:
    print("Shape of batch_rri:", batch_rri.shape)  # e.g. [4, 1, 500]
    print("Shape of batch_labels:", batch_labels.shape)  # e.g. [4]
    break
# Out:
# Shape of batch_rri: torch.Size([10, 1, 500])
# Shape of batch_labels: torch.Size([10])

# %%
# Training loop

# Instantiate the model
model = ConvPoolCNN()
#model = SimpleFFN()
#model = CNN_more_simple()
#model = CNN_even_more_simple()

criterion = nn.BCEWithLogitsLoss() # for binary classification
optimizer = optim.Adam(model.parameters(), lr=1e-3)

num_epochs = 100

# Optional: Lists to store metrics over time
train_losses = []
train_accuracies = []

val_losses = []
val_accuracies = []


for epoch in range(num_epochs):
    start_time = time.time()

    model.train()

    total_train_loss = 0.0
    train_correct = 0
    train_total = 0
    
    for batch_idx, (rri_batch, labels) in enumerate(train_loader):
        # rri_batch shape: [batch_size, 1, sequence_length]
        rri_batch = rri_batch.to(device)  # Move data to GPU if available

        # labels shape is [batch_size]; make it [batch_size, 1] if needed
        labels = labels.to(device).unsqueeze(1)

        # Forward pass
        outputs = model(rri_batch)  # shape: [batch_size, 1]
        loss = criterion(outputs, labels)

        # Backprop
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        total_train_loss += loss.item()

        # --------------------
        # Compute training accuracy for this batch
        # Sigmoid to get probabilities. Classification threshold at probability=0.5.
        predicted = (torch.sigmoid(outputs) > 0.5).float()  # shape: [batch_size, 1]
        # Compare predicted vs. labels
        correct_tensor = (predicted == labels).float()
        # Sum up correct predictions
        train_correct += correct_tensor.sum().item()
        # Count total labels
        train_total += labels.size(0)

    # After going through the training loader, compute average loss
    avg_train_loss = total_train_loss / len(train_loader)
    # Compute training accuracy
    train_acc = train_correct / train_total
    
    train_losses.append(avg_train_loss)
    train_accuracies.append(train_acc)

    # --------------------
    # Validation
    model.eval()  # set model to eval mode
    total_val_loss = 0.0
    val_correct = 0
    val_total = 0

    with torch.no_grad():
        for rri_batch_val, labels_val in val_loader:
            rri_batch_val = rri_batch_val.to(device) # Move validation data to GPU
            labels_val = labels_val.to(device).unsqueeze(1)  # Ensure labels match output shape

            outputs_val = model(rri_batch_val)  # shape: [batch_size, 1]

            loss = criterion(outputs_val, labels_val)
            total_val_loss += loss.item()

            # BCEWithLogitsLoss threshold
            predicted_val = (torch.sigmoid(outputs_val) > 0.5).float()

            # Compare predicted vs. labels
            correct_tensor_val = (predicted_val == labels_val).float()
            val_correct += correct_tensor_val.sum().item()
            val_total += labels_val.size(0)
            
    avg_val_loss = total_val_loss / len(val_loader)
    val_acc = val_correct / val_total

    val_losses.append(avg_val_loss)
    val_accuracies.append(val_acc)
    
    end_time = time.time()

    print(f"Epoch [{epoch+1}/{num_epochs}] "
          f" -  Train loss: {avg_train_loss:.4f}, Train acc: {train_acc*100:.2f}% "
          f" -  Val loss: {avg_val_loss:.4f}, Val acc: {val_acc*100:.2f}% "
          f" -  Time: {end_time - start_time:.2f}s")

print("\nTraining complete.")
print("Final training accuracy: {:.2f}%".format(train_accuracies[-1]*100))
print("Final validation accuracy: {:.2f}%".format(val_accuracies[-1]*100))
# Out:
# Epoch [1/100]  -  Train loss: 0.6954, Train acc: 50.00%  -  Val loss: 0.7128, Val acc: 38.03%  -  Time: 4.36s
# Epoch [2/100]  -  Train loss: 0.6936, Train acc: 50.00%  -  Val loss: 0.6727, Val acc: 61.88%  -  Time: 4.58s
# Epoch [3/100]  -  Train loss: 0.6859, Train acc: 50.00%  -  Val loss: 0.6471, Val acc: 61.97%  -  Time: 3.80s
# Epoch [4/100]  -  Train loss: 0.6850, Train acc: 50.00%  -  Val loss: 0.6656, Val acc: 61.88%  -  Time: 4.06s
# Epoch [5/100]  -  Train loss: 0.6751, Train acc: 50.00%  -  Val loss: 0.6863, Val acc: 66.82%  -  Time: 4.11s
# Epoch [6/100]  -  Train loss: 0.6684, Train acc: 70.00%  -  Val loss: 0.6820, Val acc: 70.93%  -  Time: 4.45s
# Epoch [7/100]  -  Train loss: 0.6488, Train acc: 70.00%  -  Val loss: 0.6572, Val acc: 61.88%  -  Time: 4.09s
# Epoch [8/100]  -  Train loss: 0.6205, Train acc: 90.00%  -  Val loss: 0.6860, Val acc: 52.29%  -  Time: 3.39s
# Epoch [9/100]  -  Train loss: 0.6033, Train acc: 80.00%  -  Val loss: 0.6207, Val acc: 61.79%  -  Time: 3.10s
# Epoch [10/100]  -  Train loss: 0.5703, Train acc: 70.00%  -  Val loss: 0.6220, Val acc: 61.70%  -  Time: 3.05s
# Epoch [11/100]  -  Train loss: 0.5149, Train acc: 90.00%  -  Val loss: 0.7031, Val acc: 47.26%  -  Time: 2.90s
# Epoch [12/100]  -  Train loss: 0.5187, Train acc: 80.00%  -  Val loss: 0.6505, Val acc: 61.52%  -  Time: 2.67s
# Epoch [13/100]  -  Train loss: 0.4844, Train acc: 80.00%  -  Val loss: 0.6526, Val acc: 61.06%  -  Time: 2.62s
# Epoch [14/100]  -  Train loss: 0.4126, Train acc: 80.00%  -  Val loss: 0.8360, Val acc: 33.46%  -  Time: 2.45s
# Epoch [15/100]  -  Train loss: 0.5087, Train acc: 60.00%  -  Val loss: 0.6839, Val acc: 60.88%  -  Time: 2.35s
# Epoch [16/100]  -  Train loss: 0.3590, Train acc: 90.00%  -  Val loss: 0.7531, Val acc: 61.24%  -  Time: 2.21s
# Epoch [17/100]  -  Train loss: 0.4265, Train acc: 80.00%  -  Val loss: 0.6821, Val acc: 61.43%  -  Time: 2.19s
# Epoch [18/100]  -  Train loss: 0.3160, Train acc: 90.00%  -  Val loss: 0.7487, Val acc: 56.31%  -  Time: 2.05s
# Epoch [19/100]  -  Train loss: 0.3712, Train acc: 80.00%  -  Val loss: 0.6894, Val acc: 66.45%  -  Time: 2.24s
# Epoch [20/100]  -  Train loss: 0.2821, Train acc: 90.00%  -  Val loss: 0.7325, Val acc: 60.60%  -  Time: 2.16s
# Epoch [21/100]  -  Train loss: 0.2779, Train acc: 90.00%  -  Val loss: 0.7729, Val acc: 60.33%  -  Time: 2.23s
# Epoch [22/100]  -  Train loss: 0.2766, Train acc: 90.00%  -  Val loss: 0.7946, Val acc: 58.87%  -  Time: 3.05s
# Epoch [23/100]  -  Train loss: 0.2146, Train acc: 100.00%  -  Val loss: 1.0087, Val acc: 48.26%  -  Time: 6.20s
# Epoch [24/100]  -  Train loss: 0.3227, Train acc: 90.00%  -  Val loss: 0.8652, Val acc: 60.24%  -  Time: 4.58s
# Epoch [25/100]  -  Train loss: 0.2338, Train acc: 90.00%  -  Val loss: 0.9409, Val acc: 60.79%  -  Time: 5.26s
# Epoch [26/100]  -  Train loss: 0.3219, Train acc: 80.00%  -  Val loss: 0.8716, Val acc: 60.88%  -  Time: 6.84s
# Epoch [27/100]  -  Train loss: 0.2431, Train acc: 90.00%  -  Val loss: 0.7700, Val acc: 65.08%  -  Time: 5.83s
# Epoch [28/100]  -  Train loss: 0.2035, Train acc: 90.00%  -  Val loss: 0.8344, Val acc: 62.52%  -  Time: 5.65s
# Epoch [29/100]  -  Train loss: 0.2555, Train acc: 80.00%  -  Val loss: 0.8368, Val acc: 61.24%  -  Time: 5.17s
# Epoch [30/100]  -  Train loss: 0.1603, Train acc: 100.00%  -  Val loss: 0.9124, Val acc: 60.51%  -  Time: 4.34s
# Epoch [31/100]  -  Train loss: 0.1975, Train acc: 90.00%  -  Val loss: 0.9279, Val acc: 60.24%  -  Time: 3.81s
# Epoch [32/100]  -  Train loss: 0.1654, Train acc: 100.00%  -  Val loss: 1.0050, Val acc: 55.94%  -  Time: 3.47s
# Epoch [33/100]  -  Train loss: 0.1351, Train acc: 100.00%  -  Val loss: 1.2056, Val acc: 52.19%  -  Time: 3.98s
# Epoch [34/100]  -  Train loss: 0.1967, Train acc: 100.00%  -  Val loss: 1.0379, Val acc: 58.23%  -  Time: 4.15s
# Epoch [35/100]  -  Train loss: 0.1268, Train acc: 100.00%  -  Val loss: 1.1101, Val acc: 60.05%  -  Time: 3.57s
# Epoch [36/100]  -  Train loss: 0.1955, Train acc: 90.00%  -  Val loss: 1.0963, Val acc: 59.51%  -  Time: 3.26s
# Epoch [37/100]  -  Train loss: 0.1251, Train acc: 100.00%  -  Val loss: 1.1813, Val acc: 56.31%  -  Time: 3.89s
# Epoch [38/100]  -  Train loss: 0.1050, Train acc: 100.00%  -  Val loss: 1.3535, Val acc: 52.01%  -  Time: 3.76s
# Epoch [39/100]  -  Train loss: 0.1651, Train acc: 90.00%  -  Val loss: 1.1895, Val acc: 58.04%  -  Time: 3.00s
# Epoch [40/100]  -  Train loss: 0.0710, Train acc: 100.00%  -  Val loss: 1.2768, Val acc: 60.15%  -  Time: 2.87s
# Epoch [41/100]  -  Train loss: 0.1238, Train acc: 90.00%  -  Val loss: 1.3055, Val acc: 59.51%  -  Time: 2.86s
# Epoch [42/100]  -  Train loss: 0.0912, Train acc: 100.00%  -  Val loss: 1.3777, Val acc: 57.59%  -  Time: 2.80s
# Epoch [43/100]  -  Train loss: 0.0555, Train acc: 100.00%  -  Val loss: 1.6223, Val acc: 54.30%  -  Time: 3.06s
# Epoch [44/100]  -  Train loss: 0.1079, Train acc: 100.00%  -  Val loss: 1.4974, Val acc: 57.04%  -  Time: 3.79s
# Epoch [45/100]  -  Train loss: 0.0443, Train acc: 100.00%  -  Val loss: 1.5512, Val acc: 59.23%  -  Time: 3.56s
# Epoch [46/100]  -  Train loss: 0.0615, Train acc: 100.00%  -  Val loss: 1.6305, Val acc: 59.32%  -  Time: 3.42s
# Epoch [47/100]  -  Train loss: 0.0646, Train acc: 100.00%  -  Val loss: 1.6680, Val acc: 57.68%  -  Time: 3.50s
# Epoch [48/100]  -  Train loss: 0.0296, Train acc: 100.00%  -  Val loss: 1.8434, Val acc: 55.94%  -  Time: 3.87s
# Epoch [49/100]  -  Train loss: 0.0525, Train acc: 100.00%  -  Val loss: 1.9421, Val acc: 56.76%  -  Time: 3.96s
# Epoch [50/100]  -  Train loss: 0.0380, Train acc: 100.00%  -  Val loss: 1.9955, Val acc: 56.58%  -  Time: 3.35s
# Epoch [51/100]  -  Train loss: 0.0182, Train acc: 100.00%  -  Val loss: 2.1105, Val acc: 57.50%  -  Time: 3.55s
# Epoch [52/100]  -  Train loss: 0.0287, Train acc: 100.00%  -  Val loss: 2.2368, Val acc: 57.04%  -  Time: 3.25s
# Epoch [53/100]  -  Train loss: 0.0260, Train acc: 100.00%  -  Val loss: 2.3927, Val acc: 55.67%  -  Time: 3.55s
# Epoch [54/100]  -  Train loss: 0.0131, Train acc: 100.00%  -  Val loss: 2.6168, Val acc: 53.93%  -  Time: 3.19s
# Epoch [55/100]  -  Train loss: 0.0239, Train acc: 100.00%  -  Val loss: 2.5611, Val acc: 55.58%  -  Time: 3.18s
# Epoch [56/100]  -  Train loss: 0.0098, Train acc: 100.00%  -  Val loss: 2.5548, Val acc: 56.58%  -  Time: 3.27s
# Epoch [57/100]  -  Train loss: 0.0104, Train acc: 100.00%  -  Val loss: 2.5822, Val acc: 57.13%  -  Time: 3.42s
# Epoch [58/100]  -  Train loss: 0.0123, Train acc: 100.00%  -  Val loss: 2.6001, Val acc: 57.31%  -  Time: 2.97s
# Epoch [59/100]  -  Train loss: 0.0087, Train acc: 100.00%  -  Val loss: 2.6080, Val acc: 57.13%  -  Time: 2.58s
# Epoch [60/100]  -  Train loss: 0.0080, Train acc: 100.00%  -  Val loss: 2.6249, Val acc: 57.31%  -  Time: 2.56s
# Epoch [61/100]  -  Train loss: 0.0109, Train acc: 100.00%  -  Val loss: 2.6748, Val acc: 57.22%  -  Time: 2.21s
# Epoch [62/100]  -  Train loss: 0.0091, Train acc: 100.00%  -  Val loss: 2.7700, Val acc: 57.59%  -  Time: 2.23s
# Epoch [63/100]  -  Train loss: 0.0062, Train acc: 100.00%  -  Val loss: 2.8883, Val acc: 57.86%  -  Time: 2.15s
# Epoch [64/100]  -  Train loss: 0.0075, Train acc: 100.00%  -  Val loss: 2.9775, Val acc: 57.59%  -  Time: 2.35s
# Epoch [65/100]  -  Train loss: 0.0069, Train acc: 100.00%  -  Val loss: 3.0365, Val acc: 57.40%  -  Time: 2.47s
# Epoch [66/100]  -  Train loss: 0.0044, Train acc: 100.00%  -  Val loss: 3.1053, Val acc: 56.31%  -  Time: 2.52s
# Epoch [67/100]  -  Train loss: 0.0042, Train acc: 100.00%  -  Val loss: 3.1952, Val acc: 55.85%  -  Time: 2.72s
# Epoch [68/100]  -  Train loss: 0.0047, Train acc: 100.00%  -  Val loss: 3.2983, Val acc: 55.39%  -  Time: 2.59s
# Epoch [69/100]  -  Train loss: 0.0041, Train acc: 100.00%  -  Val loss: 3.4052, Val acc: 55.67%  -  Time: 2.67s
# Epoch [70/100]  -  Train loss: 0.0031, Train acc: 100.00%  -  Val loss: 3.5101, Val acc: 55.21%  -  Time: 2.65s
# Epoch [71/100]  -  Train loss: 0.0027, Train acc: 100.00%  -  Val loss: 3.6073, Val acc: 55.21%  -  Time: 2.98s
# Epoch [72/100]  -  Train loss: 0.0030, Train acc: 100.00%  -  Val loss: 3.6911, Val acc: 55.30%  -  Time: 3.88s
# Epoch [73/100]  -  Train loss: 0.0031, Train acc: 100.00%  -  Val loss: 3.7621, Val acc: 55.30%  -  Time: 4.01s
# Epoch [74/100]  -  Train loss: 0.0028, Train acc: 100.00%  -  Val loss: 3.8260, Val acc: 54.84%  -  Time: 3.78s
# Epoch [75/100]  -  Train loss: 0.0023, Train acc: 100.00%  -  Val loss: 3.8889, Val acc: 54.02%  -  Time: 4.03s
# Epoch [76/100]  -  Train loss: 0.0022, Train acc: 100.00%  -  Val loss: 3.9494, Val acc: 53.66%  -  Time: 3.95s
# Epoch [77/100]  -  Train loss: 0.0024, Train acc: 100.00%  -  Val loss: 3.9973, Val acc: 53.66%  -  Time: 3.91s
# Epoch [78/100]  -  Train loss: 0.0024, Train acc: 100.00%  -  Val loss: 4.0307, Val acc: 53.93%  -  Time: 4.56s
# Epoch [79/100]  -  Train loss: 0.0020, Train acc: 100.00%  -  Val loss: 4.0595, Val acc: 54.11%  -  Time: 4.55s
# Epoch [80/100]  -  Train loss: 0.0018, Train acc: 100.00%  -  Val loss: 4.0877, Val acc: 54.75%  -  Time: 4.06s
# Epoch [81/100]  -  Train loss: 0.0018, Train acc: 100.00%  -  Val loss: 4.1127, Val acc: 54.94%  -  Time: 4.02s
# Epoch [82/100]  -  Train loss: 0.0018, Train acc: 100.00%  -  Val loss: 4.1323, Val acc: 55.03%  -  Time: 3.82s
# Epoch [83/100]  -  Train loss: 0.0017, Train acc: 100.00%  -  Val loss: 4.1464, Val acc: 54.84%  -  Time: 3.84s
# Epoch [84/100]  -  Train loss: 0.0015, Train acc: 100.00%  -  Val loss: 4.1568, Val acc: 54.84%  -  Time: 3.42s
# Epoch [85/100]  -  Train loss: 0.0013, Train acc: 100.00%  -  Val loss: 4.1660, Val acc: 55.03%  -  Time: 2.83s
# Epoch [86/100]  -  Train loss: 0.0013, Train acc: 100.00%  -  Val loss: 4.1750, Val acc: 54.39%  -  Time: 2.57s
# Epoch [87/100]  -  Train loss: 0.0013, Train acc: 100.00%  -  Val loss: 4.1847, Val acc: 54.57%  -  Time: 2.42s
# Epoch [88/100]  -  Train loss: 0.0013, Train acc: 100.00%  -  Val loss: 4.1958, Val acc: 55.03%  -  Time: 2.31s
# Epoch [89/100]  -  Train loss: 0.0012, Train acc: 100.00%  -  Val loss: 4.2092, Val acc: 55.30%  -  Time: 2.30s
# Epoch [90/100]  -  Train loss: 0.0011, Train acc: 100.00%  -  Val loss: 4.2248, Val acc: 55.48%  -  Time: 2.19s
# Epoch [91/100]  -  Train loss: 0.0011, Train acc: 100.00%  -  Val loss: 4.2415, Val acc: 55.39%  -  Time: 2.14s
# Epoch [92/100]  -  Train loss: 0.0010, Train acc: 100.00%  -  Val loss: 4.2572, Val acc: 55.21%  -  Time: 2.14s
# Epoch [93/100]  -  Train loss: 0.0010, Train acc: 100.00%  -  Val loss: 4.2702, Val acc: 55.30%  -  Time: 2.17s
# Epoch [94/100]  -  Train loss: 0.0010, Train acc: 100.00%  -  Val loss: 4.2799, Val acc: 55.30%  -  Time: 2.12s
# Epoch [95/100]  -  Train loss: 0.0010, Train acc: 100.00%  -  Val loss: 4.2870, Val acc: 55.48%  -  Time: 2.14s
# Epoch [96/100]  -  Train loss: 0.0009, Train acc: 100.00%  -  Val loss: 4.2934, Val acc: 55.58%  -  Time: 2.27s
# Epoch [97/100]  -  Train loss: 0.0009, Train acc: 100.00%  -  Val loss: 4.3007, Val acc: 55.76%  -  Time: 2.33s
# Epoch [98/100]  -  Train loss: 0.0009, Train acc: 100.00%  -  Val loss: 4.3102, Val acc: 55.67%  -  Time: 2.40s
# Epoch [99/100]  -  Train loss: 0.0009, Train acc: 100.00%  -  Val loss: 4.3226, Val acc: 55.67%  -  Time: 2.52s
# Epoch [100/100]  -  Train loss: 0.0009, Train acc: 100.00%  -  Val loss: 4.3380, Val acc: 55.67%  -  Time: 2.54s
#
# Training complete.
# Final training accuracy: 100.00%
# Final validation accuracy: 55.67%

# %%
# Plot accuracies

# Assuming you have these lists defined:
# train_accuracies, val_accuracies, train_losses, val_losses

epoch_list = [epoch + 1 for epoch in range(num_epochs)]

# Create the figure and the first subplot (for accuracy)
fig, ax1 = plt.subplots()

lw = 0.8 # Line width

# Plot the accuracy data on the first y-axis
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.plot(epoch_list, train_accuracies, label='Train acc', color='tab:red', linewidth=lw)
ax1.plot(epoch_list, val_accuracies, label='Val acc', color='tab:blue', linewidth=lw)
ax1.set_ylim(-0.02, 1.02)
ax1.grid(True, linestyle='solid', linewidth=0.5)

# Create a second y-axis that shares the same x-axis
ax2 = ax1.twinx()  # Instantiate a second axes that shares the same x-axis

# Plot the loss data on the second y-axis
ax2.set_ylabel('Loss')
ax2.plot(epoch_list, train_losses, label='Train loss', color='tab:green', linewidth=lw)
ax2.plot(epoch_list, val_losses, label='Val loss', color='tab:purple', linewidth=lw)
ax2.set_ylim(-0.02, max(max(train_losses), max(val_losses)))
ax2.set_xlim(left=-1) # Lower bound

# Combine the legends from both axes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()

# Place legend outside the plot below
plt.legend(lines + lines2, labels + labels2, loc='upper center', bbox_to_anchor=(0.5, -0.15),
           fancybox=True, shadow=True, ncol=2)

plt.title('Training and validation performance')
fig.tight_layout()  # otherwise the right y-label might be slightly clipped
plt.show()
